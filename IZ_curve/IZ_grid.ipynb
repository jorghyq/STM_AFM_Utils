# %%
import os
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd
import os
import re
from fit_current import fit_current
#from fit_plot import fit_plot
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
file_path = './test/Z-Spectroscopy_grid_dimer1_461.dat'
data = pd.read_csv(file_path,sep='\t',skiprows=21)
height = data['Z (m)']
current = data['Current [bwd] (A)']
log_current = np.log(current)
z = np.polyfit(height, log_current, 1)
x0 = z[0]*z[0]*9.537e-21
print x0
current_fit = np.exp(z[1])*np.exp(z[0]*height)
log_current_fit = z[0]*height + z[1] 
plt.plot(height,current,'o',height,current_fit,'r')
print
# Out:
# 3.35348901594

# %%
base_dir = './test/'
files = os.listdir(base_dir)
size = 25
begin = None
end = None
grid = np.zeros((size,size))
error = np.zeros((size,size))
topo = np.zeros((size,size))
for item in files:
    match = re.search(r'Z-Spectroscopy_grid_dimer5_',item)
    if match:
        ind = int(item.split('_')[-1][-7:-4])-1
        #print ind
        ind_x = ind / size
        ind_y = ind % size
        #print ind_x, ind_y,ind
        z, x0, e, z_set = fit_current(base_dir + item,begin,end,1,1)
        grid[ind_x,ind_y] = x0
        error[ind_x,ind_y] = e
        topo[ind_x,ind_y] = z_set

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)
axes[0].set_title('IZ')
ax_freq = axes[0].imshow(np.flipud(grid),interpolation='nearest')
divider_freq = make_axes_locatable(axes[0])
cax_freq = divider_freq.append_axes("right", size="10%", pad=0.05)
cbar_freq = plt.colorbar(ax_freq, cax=cax_freq, format="%.2f")
axes[1].set_title('error')
ax_error = axes[1].imshow(np.flipud(error),interpolation='nearest')
divider_error = make_axes_locatable(axes[1])
cax_error = divider_error.append_axes("right", size="10%", pad=0.05)
cbar_error = plt.colorbar(ax_error, cax=cax_error, format="%.2f")
axes[2].set_title('topo')
ax_topo = axes[2].imshow(np.flipud(topo),interpolation='nearest')
divider_topo = make_axes_locatable(axes[2])
cax_topo = divider_topo.append_axes("right", size="10%", pad=0.05)
cbar_topo = plt.colorbar(ax_topo, cax=cax_topo, format="%.2f")
plt.tight_layout()

# %%
data = pd.read_csv('./test/KPFM_test_CN_constz_grid2_204.dat',sep='\t',skiprows=21)
bias = data['Bias calc (V)']
freq = data['Frequency Shift (Hz)']

z = np.polyfit(bias[:100], freq[:100], 2)
fit = z[0] * bias * bias + z[1] * bias + z[2]
error = sum(abs(freq - fit))
plt.plot(bias, freq, 'o', bias, fit, 'r')
plt.show()
print z[1]/(2*z[0])
# Out:
# -0.345841992963

# %%
data = pd.read_csv('./test/KPFM_0_204.dat',sep='\t',skiprows=16)
bias = data['Bias calc (V)']
freq = data['Frequency Shift (Hz)']
z = np.polyfit(bias, freq, 2)
fit = z[0] * bias * bias + z[1] * bias + z[2]
error = sum(abs(freq - fit))
plt.plot(bias, freq, 'o', bias, fit, 'r')
plt.show()
print z[1]/(2*z[0])*1000
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-14-c039b898f678> in <module>()
# ----> 1 data = pd.read_csv('./test/KPFM_0_204.dat',sep='\t',skiprows=16)
#       2 bias = data['Bias calc (V)']
#       3 freq = data['Frequency Shift (Hz)']
#       4 z = np.polyfit(bias, freq, 2)
#       5 fit = z[0] * bias * bias + z[1] * bias + z[2]
#
# /usr/lib64/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     489                     skip_blank_lines=skip_blank_lines)
#     490
# --> 491         return _read(filepath_or_buffer, kwds)
#     492
#     493     parser_f.__name__ = name
#
# /usr/lib64/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     266
#     267     # Create the parser.
# --> 268     parser = TextFileReader(filepath_or_buffer, **kwds)
#     269
#     270     if (nrows is not None) and (chunksize is not None):
#
# /usr/lib64/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     581             self.options['has_index_names'] = kwds['has_index_names']
#     582
# --> 583         self._make_engine(self.engine)
#     584
#     585     def _get_options_with_defaults(self, engine):
#
# /usr/lib64/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     722     def _make_engine(self, engine='c'):
#     723         if engine == 'c':
# --> 724             self._engine = CParserWrapper(self.f, **self.options)
#     725         else:
#     726             if engine == 'python':
#
# /usr/lib64/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1091         kwds['allow_leading_cols'] = self.index_col is not False
#    1092
# -> 1093         self._reader = _parser.TextReader(src, **kwds)
#    1094
#    1095         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3253)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6112)()
#
# IOError: File ./test/KPFM_0_204.dat does not exist
